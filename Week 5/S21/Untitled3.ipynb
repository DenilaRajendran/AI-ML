# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense, Dropout, Conv1D, MaxPooling1D
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import matplotlib.pyplot as plt

# Model configuration
max_sequence_length = 100
num_distinct_words = 10000
embedding_output_dims = 15
loss_function = 'binary_crossentropy'
optimizer = 'adam'
additional_metrics = ['accuracy']
number_of_epochs = 100
verbosity_mode = True
validation_split = 0.20

# Load dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=num_distinct_words)
print(x_train.shape)
print(x_test.shape)

# Here, you'd normally test first that the model generalizes and concatenate all data
# (that is, normally, you'd perform e.g. K-fold Cross Validation first)
# Then, you can use all data for a full training run. Now, we'll use x_train for training only.

# Pad all sequences
padded_inputs = pad_sequences(x_train, maxlen=max_sequence_length, value = 0.0) # 0.0 because it corresponds with <PAD>
padded_inputs_test = pad_sequences(x_test, maxlen=max_sequence_length, value = 0.0) # 0.0 because it corresponds with <PAD>

# Obtain 3 texts
for i in np.random.randint(0, len(padded_inputs), 3):
  INDEX_FROM=3   # word index offset
  word_to_id = imdb.get_word_index()
  word_to_id = {k:(v+INDEX_FROM) for k,v in word_to_id.items()}
  word_to_id["<PAD>"] = 0
  word_to_id["<START>"] = 1
  word_to_id["<UNK>"] = 2
  word_to_id["<UNUSED>"] = 3

  id_to_word = {value:key for key,value in word_to_id.items()}
  print('=================================================')
  print(f'Sample = {i} | Length = {len(padded_inputs[i])}')
  print('=================================================')
  print(' '.join(id_to_word[id] for id in padded_inputs[i] ))

# Define the Keras model
model = Sequential()
model.add(Embedding(num_distinct_words, embedding_output_dims, input_length=max_sequence_length))
model.add(Dropout(0.50))
model.add(Conv1D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(Dropout(0.50))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dropout(0.50))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer=optimizer, loss=loss_function, metrics=additional_metrics)

# Give a summary
model.summary()

# Train the model
history = model.fit(padded_inputs, y_train, epochs=number_of_epochs, verbose=verbosity_mode, validation_split=validation_split)

# Test the model after training
test_results = model.evaluate(padded_inputs_test, y_test, verbose=False)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {100*test_results[1]}%')

# Visualize history
# Plot history: Validation loss
plt.plot(history.history['val_loss'])
plt.title('Validation loss history')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.plot(history.history['val_accuracy'])
plt.title('Validation accuracy history')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (25000,)
# (25000,)
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# =================================================
# Sample = 8506 | Length = 100
# =================================================
# did you know that demons in hell spend their free time dancing around doing ballet in their <UNK> you didn't neither did i until i watched this movie one learns something new everyday br br is this movie actually worth watching now that's a <UNK> i can't in good conscience recommend it to anyone as it's quite disturbing in its own bizarre way yet its unintentional <UNK> is what makes it worth watching you decide what you're going to do i <UNK> for myself it made me feel uncomfortable seeing demons constantly doing <UNK> ballet moves now that's just wrong
# =================================================
# Sample = 3807 | Length = 100
# =================================================
# <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <START> largely dense road movie with some comic relief provided by the excellent john <UNK> although he is really sending up his performance in <UNK> towers seems to flip from over the top slapstick to <UNK> sentimentality at the drop of a hat and the worst part of the film is that martin and hawn have to find themselves who they are etc see it at your peril
# =================================================
# Sample = 1336 | Length = 100
# =================================================
# <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <START> i really liked this movie i have seen several gene kelly flicks and this is one of his best i would actually put it above his more famous american in paris sometimes it seems the story gets lost in gene kelly movies to the wonderful dance and song numbers but not in this movie it is definitely worth renting
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.5216 - loss: 0.6893 - val_accuracy: 0.8008 - val_loss: 0.5057
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.8119 - loss: 0.4225 - val_accuracy: 0.8464 - val_loss: 0.3506
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.8732 - loss: 0.2969 - val_accuracy: 0.8558 - val_loss: 0.3316
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.8947 - loss: 0.2561 - val_accuracy: 0.8462 - val_loss: 0.3454
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9098 - loss: 0.2260 - val_accuracy: 0.8522 - val_loss: 0.3371
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9135 - loss: 0.2083 - val_accuracy: 0.8494 - val_loss: 0.3558
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9230 - loss: 0.1975 - val_accuracy: 0.8496 - val_loss: 0.3638
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9212 - loss: 0.1956 - val_accuracy: 0.8438 - val_loss: 0.3738
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9283 - loss: 0.1775 - val_accuracy: 0.8432 - val_loss: 0.3945
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9269 - loss: 0.1778 - val_accuracy: 0.8382 - val_loss: 0.4050
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9292 - loss: 0.1759 - val_accuracy: 0.8364 - val_loss: 0.4104
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9380 - loss: 0.1563 - val_accuracy: 0.8358 - val_loss: 0.4277
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9391 - loss: 0.1526 - val_accuracy: 0.8364 - val_loss: 0.4448
# Epoch 14/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9389 - loss: 0.1514 - val_accuracy: 0.8336 - val_loss: 0.4401
# Epoch 15/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9412 - loss: 0.1455 - val_accuracy: 0.8326 - val_loss: 0.4578
# Epoch 16/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9425 - loss: 0.1447 - val_accuracy: 0.8348 - val_loss: 0.4561
# Epoch 17/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9434 - loss: 0.1399 - val_accuracy: 0.8350 - val_loss: 0.4603
# Epoch 18/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9418 - loss: 0.1438 - val_accuracy: 0.8332 - val_loss: 0.4699
# Epoch 19/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9476 - loss: 0.1351 - val_accuracy: 0.8336 - val_loss: 0.4790
# Epoch 20/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9496 - loss: 0.1293 - val_accuracy: 0.8362 - val_loss: 0.4917
# Epoch 21/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9449 - loss: 0.1385 - val_accuracy: 0.8304 - val_loss: 0.5017
# Epoch 22/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9493 - loss: 0.1291 - val_accuracy: 0.8290 - val_loss: 0.5122
# Epoch 23/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9512 - loss: 0.1233 - val_accuracy: 0.8286 - val_loss: 0.5086
# Epoch 24/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9481 - loss: 0.1290 - val_accuracy: 0.8308 - val_loss: 0.5153
# Epoch 25/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9500 - loss: 0.1270 - val_accuracy: 0.8296 - val_loss: 0.5281
# Epoch 26/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9479 - loss: 0.1321 - val_accuracy: 0.8318 - val_loss: 0.5176
# Epoch 27/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9521 - loss: 0.1246 - val_accuracy: 0.8270 - val_loss: 0.5240
# Epoch 28/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9506 - loss: 0.1230 - val_accuracy: 0.8270 - val_loss: 0.5252
# Epoch 29/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9528 - loss: 0.1228 - val_accuracy: 0.8274 - val_loss: 0.5390
# Epoch 30/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9536 - loss: 0.1186 - val_accuracy: 0.8272 - val_loss: 0.5364
# Epoch 31/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9513 - loss: 0.1198 - val_accuracy: 0.8278 - val_loss: 0.5562
# Epoch 32/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9546 - loss: 0.1139 - val_accuracy: 0.8274 - val_loss: 0.5653
# Epoch 33/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9536 - loss: 0.1197 - val_accuracy: 0.8260 - val_loss: 0.5755
# Epoch 34/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9540 - loss: 0.1157 - val_accuracy: 0.8276 - val_loss: 0.5791
# Epoch 35/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9515 - loss: 0.1187 - val_accuracy: 0.8300 - val_loss: 0.5741
# Epoch 36/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9563 - loss: 0.1122 - val_accuracy: 0.8260 - val_loss: 0.5735
# Epoch 37/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9575 - loss: 0.1084 - val_accuracy: 0.8260 - val_loss: 0.5708
# Epoch 38/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9571 - loss: 0.1077 - val_accuracy: 0.8230 - val_loss: 0.5877
# Epoch 39/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9574 - loss: 0.1096 - val_accuracy: 0.8276 - val_loss: 0.5862
# Epoch 40/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9547 - loss: 0.1133 - val_accuracy: 0.8240 - val_loss: 0.5960
# Epoch 41/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9596 - loss: 0.1034 - val_accuracy: 0.8258 - val_loss: 0.5973
# Epoch 42/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9574 - loss: 0.1105 - val_accuracy: 0.8250 - val_loss: 0.6014
# Epoch 43/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9591 - loss: 0.1047 - val_accuracy: 0.8264 - val_loss: 0.6085
# Epoch 44/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9604 - loss: 0.1048 - val_accuracy: 0.8270 - val_loss: 0.6048
# Epoch 45/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9586 - loss: 0.1114 - val_accuracy: 0.8254 - val_loss: 0.6067
# Epoch 46/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9589 - loss: 0.1030 - val_accuracy: 0.8252 - val_loss: 0.6132
# Epoch 47/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9551 - loss: 0.1127 - val_accuracy: 0.8236 - val_loss: 0.5972
# Epoch 48/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9599 - loss: 0.1035 - val_accuracy: 0.8274 - val_loss: 0.6192
# Epoch 49/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9596 - loss: 0.1048 - val_accuracy: 0.8208 - val_loss: 0.6326
# Epoch 50/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9592 - loss: 0.1004 - val_accuracy: 0.8258 - val_loss: 0.6334
# Epoch 51/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9590 - loss: 0.1042 - val_accuracy: 0.8234 - val_loss: 0.6361
# Epoch 52/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9596 - loss: 0.1031 - val_accuracy: 0.8234 - val_loss: 0.6300
# Epoch 53/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9592 - loss: 0.1005 - val_accuracy: 0.8230 - val_loss: 0.6229
# Epoch 54/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9610 - loss: 0.0972 - val_accuracy: 0.8246 - val_loss: 0.6329
# Epoch 55/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9611 - loss: 0.0999 - val_accuracy: 0.8230 - val_loss: 0.6437
# Epoch 56/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9612 - loss: 0.0972 - val_accuracy: 0.8242 - val_loss: 0.6399
# Epoch 57/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9632 - loss: 0.0944 - val_accuracy: 0.8236 - val_loss: 0.6369
# Epoch 58/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9581 - loss: 0.1035 - val_accuracy: 0.8146 - val_loss: 0.6666
# Epoch 59/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9626 - loss: 0.0953 - val_accuracy: 0.8244 - val_loss: 0.6584
# Epoch 60/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9633 - loss: 0.0960 - val_accuracy: 0.8238 - val_loss: 0.6457
# Epoch 61/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9611 - loss: 0.1011 - val_accuracy: 0.8210 - val_loss: 0.6497
# Epoch 62/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9611 - loss: 0.0988 - val_accuracy: 0.8252 - val_loss: 0.6458
# Epoch 63/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9604 - loss: 0.1004 - val_accuracy: 0.8282 - val_loss: 0.6420
# Epoch 64/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9599 - loss: 0.1017 - val_accuracy: 0.8242 - val_loss: 0.6406
# Epoch 65/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9623 - loss: 0.0936 - val_accuracy: 0.8250 - val_loss: 0.6337
# Epoch 66/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9648 - loss: 0.0955 - val_accuracy: 0.8242 - val_loss: 0.6544
# Epoch 67/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9611 - loss: 0.1007 - val_accuracy: 0.8246 - val_loss: 0.6577
# Epoch 68/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9641 - loss: 0.0989 - val_accuracy: 0.8244 - val_loss: 0.6527
# Epoch 69/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9587 - loss: 0.1047 - val_accuracy: 0.8212 - val_loss: 0.6486
# Epoch 70/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9618 - loss: 0.0974 - val_accuracy: 0.8200 - val_loss: 0.6693
# Epoch 71/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9636 - loss: 0.0926 - val_accuracy: 0.8202 - val_loss: 0.6625
# Epoch 72/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9626 - loss: 0.0948 - val_accuracy: 0.8206 - val_loss: 0.6634
# Epoch 73/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9619 - loss: 0.0965 - val_accuracy: 0.8206 - val_loss: 0.6929
# Epoch 74/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9605 - loss: 0.1002 - val_accuracy: 0.8212 - val_loss: 0.6712
# Epoch 75/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9627 - loss: 0.1023 - val_accuracy: 0.8234 - val_loss: 0.6666
# Epoch 76/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9681 - loss: 0.0886 - val_accuracy: 0.8234 - val_loss: 0.6637
# Epoch 77/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9663 - loss: 0.0907 - val_accuracy: 0.8250 - val_loss: 0.6724
# Epoch 78/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9654 - loss: 0.0908 - val_accuracy: 0.8240 - val_loss: 0.6765
# Epoch 79/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9643 - loss: 0.0939 - val_accuracy: 0.8242 - val_loss: 0.6801
# Epoch 80/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9620 - loss: 0.0957 - val_accuracy: 0.8244 - val_loss: 0.6816
# Epoch 81/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9620 - loss: 0.0976 - val_accuracy: 0.8242 - val_loss: 0.6660
# Epoch 82/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9642 - loss: 0.0915 - val_accuracy: 0.8250 - val_loss: 0.6825
# Epoch 83/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9666 - loss: 0.0878 - val_accuracy: 0.8188 - val_loss: 0.6812
# Epoch 84/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9646 - loss: 0.0898 - val_accuracy: 0.8180 - val_loss: 0.6967
# Epoch 85/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9669 - loss: 0.0875 - val_accuracy: 0.8206 - val_loss: 0.7171
# Epoch 86/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9642 - loss: 0.0890 - val_accuracy: 0.8200 - val_loss: 0.7278
# Epoch 87/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9668 - loss: 0.0882 - val_accuracy: 0.8208 - val_loss: 0.7133
# Epoch 88/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9651 - loss: 0.0910 - val_accuracy: 0.8156 - val_loss: 0.7425
# Epoch 89/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9654 - loss: 0.0880 - val_accuracy: 0.8158 - val_loss: 0.7213
# Epoch 90/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9650 - loss: 0.0904 - val_accuracy: 0.8210 - val_loss: 0.7206
# Epoch 91/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9650 - loss: 0.0909 - val_accuracy: 0.8192 - val_loss: 0.7332
# Epoch 92/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9677 - loss: 0.0869 - val_accuracy: 0.8226 - val_loss: 0.7256
# Epoch 93/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9663 - loss: 0.0906 - val_accuracy: 0.8220 - val_loss: 0.7076
# Epoch 94/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9635 - loss: 0.0917 - val_accuracy: 0.8204 - val_loss: 0.7036
# Epoch 95/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9660 - loss: 0.0866 - val_accuracy: 0.8192 - val_loss: 0.7218
# Epoch 96/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9680 - loss: 0.0858 - val_accuracy: 0.8206 - val_loss: 0.7077
# Epoch 97/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9667 - loss: 0.0868 - val_accuracy: 0.8198 - val_loss: 0.7179
# Epoch 98/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9662 - loss: 0.0903 - val_accuracy: 0.8204 - val_loss: 0.7202
# Epoch 99/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9655 - loss: 0.0923 - val_accuracy: 0.8208 - val_loss: 0.7236
# Epoch 100/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9670 - loss: 0.0859 - val_accuracy: 0.8246 - val_loss: 0.7321
# Test results - Loss: 0.7446313500404358 - Accuracy: 80.95600008964539%
